# %%
import sqlite3

conn = sqlite3.connect('store_management_project.db')
cursor = conn.cursor()

# Create Store table
cursor.execute('''
    CREATE TABLE Store (
        store_id INTEGER PRIMARY KEY,
        name TEXT,
        location TEXT,
        contact_number TEXT,
        opening_hours TEXT,
        closing_hours TEXT
    )
''')

# Create Employee table
cursor.execute('''
    CREATE TABLE Employee (
        employee_id INTEGER PRIMARY KEY,
        first_name TEXT,
        last_name TEXT,
        date_of_birth TEXT,
        position TEXT,
        contact_number TEXT,
        email TEXT,
        address TEXT,
        hire_date TEXT,
        salary REAL,
        store_id INTEGER,
        FOREIGN KEY (store_id) REFERENCES Store (store_id)
    )
''')

# Create Product table
cursor.execute('''
    CREATE TABLE Product (
        product_id INTEGER PRIMARY KEY,
        name TEXT,
        description TEXT,
        price REAL,
        quantity_in_stock INTEGER,
        reorder_threshold INTEGER,
        manufacturing_date TEXT,
        expiration_date TEXT,
        category_id INTEGER,
        FOREIGN KEY (category_id) REFERENCES Category (category_id)
    )
''')

# Create Category table
cursor.execute('''
    CREATE TABLE Category (
        category_id INTEGER PRIMARY KEY,
        name TEXT,
        description TEXT
    )
''')

# Create Customer table
cursor.execute('''
    CREATE TABLE Customer (
        customer_id INTEGER PRIMARY KEY,
        first_name TEXT,
        last_name TEXT,
        date_of_birth TEXT,
        contact_number TEXT,
        email TEXT,
        address TEXT
    )
''')

# Create SalesTransaction table
cursor.execute('''
    CREATE TABLE SalesTransaction (
        transaction_id INTEGER PRIMARY KEY,
        transaction_date TEXT,
        payment_method TEXT,
        total_amount REAL,
        customer_id INTEGER,
        FOREIGN KEY (customer_id) REFERENCES Customer (customer_id)
    )
''')

# Create TransactionItem table
cursor.execute('''
    CREATE TABLE TransactionItem (
        transaction_item_id INTEGER PRIMARY KEY,
        quantity INTEGER,
        subtotal REAL,
        transaction_id INTEGER,
        product_id INTEGER,
        FOREIGN KEY (transaction_id) REFERENCES SalesTransaction (transaction_id),
        FOREIGN KEY (product_id) REFERENCES Product (product_id)
    )
''')


# Create Supplier table
cursor.execute('''
    CREATE TABLE Supplier (
        supplier_id INTEGER PRIMARY KEY,
        name TEXT,
        contact_number TEXT,
        email TEXT,
        address TEXT
    )
''')

# Create Supply table
cursor.execute('''
    CREATE TABLE Supply (
        supply_id INTEGER PRIMARY KEY,
        supply_date TEXT,
        quantity_supplied INTEGER,
        unit_price REAL,
        supplier_id INTEGER,
        product_id INTEGER,
        FOREIGN KEY (supplier_id) REFERENCES Supplier (supplier_id),
        FOREIGN KEY (product_id) REFERENCES Product (product_id)
    )
''')

conn.commit()
conn.close()

# %%
import sqlite3
from faker import Faker

# Connect to the SQLite database (or create if it doesn't exist)
conn = sqlite3.connect('store_management_project.db')
cursor = conn.cursor()

# Create Store table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Store (
        store_id INTEGER PRIMARY KEY,
        name TEXT,
        location TEXT,
        contact_number TEXT,
        opening_hours TEXT,
        closing_hours TEXT
    )
''')

# Generate and insert fake data using the faker library
fake = Faker()
num_records = 10  # You can adjust the number of records you want to insert

for _ in range(num_records):
    store_name = fake.company()
    location = fake.address()
    contact_number = fake.phone_number()
    opening_hours = "09:00 AM"
    closing_hours = "06:00 PM"

    cursor.execute('''
        INSERT INTO Store (name, location, contact_number, opening_hours, closing_hours)
        VALUES (?, ?, ?, ?, ?)
    ''', (store_name, location, contact_number, opening_hours, closing_hours))

# Commit changes and close connection
conn.commit()
conn.close()

# %%
import sqlite3

conn = sqlite3.connect('store_management_project.db')
cursor = conn.cursor()

# Retrieve data from the Store table
cursor.execute('SELECT * FROM Store')
store_data = cursor.fetchall()

# Print the retrieved data
print("Store Data:")
for row in store_data:
    print(row)

# Close the connection
conn.close()

# %%
import sqlite3
from faker import Faker

# Connect to the SQLite database
conn = sqlite3.connect('store_management_project.db')
cursor = conn.cursor()

# Generate fake data using the faker library
fake = Faker()
num_records = 10  # You can adjust the number of records you want to insert


# Insert fake data into Employee table
for _ in range(num_records):
    first_name = fake.first_name()
    last_name = fake.last_name()
    date_of_birth = fake.date_of_birth()
    position = fake.job()
    contact_number = fake.phone_number()
    email = fake.email()
    address = fake.address()
    hire_date = fake.date_this_decade()
    salary = fake.random_int(min=30000, max=100000)
    store_id = fake.random_int(min=1, max=num_records)
    
    cursor.execute('''
        INSERT INTO Employee (first_name, last_name, date_of_birth, position, contact_number, email, address, hire_date, salary, store_id)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (first_name, last_name, date_of_birth, position, contact_number, email, address, hire_date, salary, store_id))

#Insert fake data to product table
for _ in range(num_records):
    product_name = fake.word()
    description = fake.sentence()
    price = fake.random_int(min=10, max=100)
    quantity_in_stock = fake.random_int(min=0, max=1000)
    reorder_threshold = fake.random_int(min=10, max=100)
    manufacturing_date = fake.date_this_decade()
    expiration_date = fake.date_between_dates(date_start=manufacturing_date, date_end='+1y')
    category_id = fake.random_int(min=1, max=num_records)  # Assuming you have categories populated already
    
    cursor.execute('''
        INSERT INTO Product (name, description, price, quantity_in_stock, reorder_threshold, manufacturing_date, expiration_date, category_id)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    ''', (product_name, description, price, quantity_in_stock, reorder_threshold, manufacturing_date, expiration_date, category_id))

# Insert fake data into Category table
for _ in range(num_records):
    category_name = fake.word()
    category_description = fake.sentence()
    
    cursor.execute('''
        INSERT INTO Category (name, description)
        VALUES (?, ?)
    ''', (category_name, category_description))

# Insert fake data into Customer table
for _ in range(num_records):
    first_name = fake.first_name()
    last_name = fake.last_name()
    date_of_birth = fake.date_of_birth()
    contact_number = fake.phone_number()
    email = fake.email()
    address = fake.address()
    
    cursor.execute('''
        INSERT INTO Customer (first_name, last_name, date_of_birth, contact_number, email, address)
        VALUES (?, ?, ?, ?, ?, ?)
    ''', (first_name, last_name, date_of_birth, contact_number, email, address))

# Insert fake data into SalesTransaction and TransactionItem tables
for _ in range(num_records):
    transaction_date = fake.date_this_year()
    payment_method = fake.random_element(elements=('Cash', 'Credit Card', 'Online Payment'))
    total_amount = fake.random_int(min=50, max=500)
    customer_id = fake.random_int(min=1, max=num_records)  # Assuming you have customers populated already

    cursor.execute('''
        INSERT INTO SalesTransaction (transaction_date, payment_method, total_amount, customer_id)
        VALUES (?, ?, ?, ?)
    ''', (transaction_date, payment_method, total_amount, customer_id))
    
    transaction_id = cursor.lastrowid  # Get the ID of the last inserted transaction

    # Assuming you have products populated already
    product_id = fake.random_int(min=1, max=num_records)
    quantity = fake.random_int(min=1, max=10)
    subtotal = quantity * total_amount  # For simplicity, assuming subtotal is calculated this way
    
    cursor.execute('''
        INSERT INTO TransactionItem (transaction_id, product_id, quantity, subtotal)
        VALUES (?, ?, ?, ?)
    ''', (transaction_id, product_id, quantity, subtotal))


# Insert fake data into Supplier table
for _ in range(num_records):
    supplier_name = fake.company()
    contact_number = fake.phone_number()
    email = fake.email()
    address = fake.address()

    cursor.execute('''
        INSERT INTO Supplier (name, contact_number, email, address)
        VALUES (?, ?, ?, ?)
    ''', (supplier_name, contact_number, email, address))

# Insert fake data into Supply table
for _ in range(num_records):
    supply_date = fake.date_this_year()
    quantity_supplied = fake.random_int(min=10, max=100)
    unit_price = fake.random_int(min=5, max=50)
    supplier_id = fake.random_int(min=1, max=num_records)  # Assuming you have suppliers populated already
    product_id = fake.random_int(min=1, max=num_records)  # Assuming you have products populated already

    cursor.execute('''
        INSERT INTO Supply (supply_date, quantity_supplied, unit_price, supplier_id, product_id)
        VALUES (?, ?, ?, ?, ?)
    ''', (supply_date, quantity_supplied, unit_price, supplier_id, product_id))


conn.commit()
conn.close()

# %%
# %pip install prettytable
# Out:
# Collecting prettytable
#   Downloading prettytable-3.8.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wcwidth in c:\users\india\appdata\local\programs\python\python311\lib\site-packages (from prettytable) (0.2.6)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.8.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#TO PRINT TABLE

import sqlite3
from prettytable import PrettyTable


conn = sqlite3.connect('store_management_project.db')
cursor = conn.cursor()

# Fetch table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = cursor.fetchall()

# Print data for each table
for table in table_names:
    table_name = table[0]
    print(f"Table: {table_name}")
    
    # Fetch column names
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    column_names = [column[1] for column in columns]
    
    # Fetch table data
    cursor.execute(f"SELECT * FROM {table_name};")
    data = cursor.fetchall()
    
   #print
    table = PrettyTable(column_names)
    for row in data:
        table.add_row(row)
    
    print(table)
    print('\n')


conn.close()
# Out:
# Table: Store
# +----------+-------------------------------+---------------------------------+-----------------------+---------------+---------------+
# | store_id |              name             |             location            |     contact_number    | opening_hours | closing_hours |
# +----------+-------------------------------+---------------------------------+-----------------------+---------------+---------------+
# |    1     |    Lewis, Wright and Miles    |  556 Mcpherson Bypass Apt. 580  |      483.895.0741     |    09:00 AM   |    06:00 PM   |
# |          |                               |      Kramerhaven, MD 42951      |                       |               |               |
# |    2     |    Davis, Brooks and Hodges   |   962 Melissa Drive Suite 555   |  +1-513-558-8673x535  |    09:00 AM   |    06:00 PM   |
# |          |                               |     Lake Robinberg, MN 29615    |                       |               |               |
# |    3     |    Costa, Nguyen and Wilson   |        75516 Gibson Rapid       |   658.483.0119x2769   |    09:00 AM   |    06:00 PM   |
# |          |                               |        Joseside, UT 08619       |                       |               |               |
# |    4     |       Zimmerman and Sons      |        Unit 7016 Box 3492       |  (217)504-8335x32792  |    09:00 AM   |    06:00 PM   |
# |          |                               |           DPO AP 34423          |                       |               |               |
# |    5     |        Foster-Saunders        |        587 Adams Mission        |      375-768-8970     |    09:00 AM   |    06:00 PM   |
# |          |                               |   New Marthaborough, VI 60568   |                       |               |               |
# |    6     |          Evans Group          |        2091 Dawson Cliffs       | +1-610-453-3004x01932 |    09:00 AM   |    06:00 PM   |
# |          |                               |       West Sean, GU 09400       |                       |               |               |
# |    7     |         Johnston Group        |    5954 Antonio Dale Apt. 857   |     (857)944-7512     |    09:00 AM   |    06:00 PM   |
# |          |                               |        Huntton, ME 63057        |                       |               |               |
# |    8     | Villarreal, Greene and Duncan |   00020 Michael Way Suite 781   |  +1-980-896-3917x026  |    09:00 AM   |    06:00 PM   |
# |          |                               |    North Edwardland, WI 95648   |                       |               |               |
# |    9     |    Drake, Bennett and Moses   |        297 Katherine Oval       |  +1-393-813-3134x1743 |    09:00 AM   |    06:00 PM   |
# |          |                               |       Hughesstad, SD 74518      |                       |               |               |
# |    10    |    Mendez, Jackson and Kirk   |         1921 Morris Well        |    698-911-2975x768   |    09:00 AM   |    06:00 PM   |
# |          |                               |     Richardsonstad, SD 34454    |                       |               |               |
# |    11    |           Miller LLC          |       89168 Martinez Ridge      |       5335867460      |    09:00 AM   |    06:00 PM   |
# |          |                               |       Sarahfort, MO 92780       |                       |               |               |
# |    12    |    Ruiz, Maxwell and Lucas    |         7764 Cox Points         |       3546297073      |    09:00 AM   |    06:00 PM   |
# |          |                               |     West Johnbury, DC 47905     |                       |               |               |
# |    13    |   Nelson, Joseph and Clayton  |      914 Elizabeth Orchard      |       5995964504      |    09:00 AM   |    06:00 PM   |
# |          |                               |       Robertbury, CO 74075      |                       |               |               |
# |    14    |        Kirby-Fernandez        |   6599 Robinson Road Apt. 253   |   518-822-9527x38844  |    09:00 AM   |    06:00 PM   |
# |          |                               |    Lake Robertbury, CO 32623    |                       |               |               |
# |    15    |            Cole Inc           |        2731 Robert Light        |  +1-375-925-4306x433  |    09:00 AM   |    06:00 PM   |
# |          |                               |       Monroeberg, OK 79890      |                       |               |               |
# |    16    |          Schmidt Ltd          |       5886 Rebecca Gateway      | 001-848-281-5006x7035 |    09:00 AM   |    06:00 PM   |
# |          |                               |      Petersmouth, CT 48437      |                       |               |               |
# |    17    |         Howell-Gregory        |          547 Jared Neck         |      398.654.7569     |    09:00 AM   |    06:00 PM   |
# |          |                               |      Lake Kaylee, IN 37166      |                       |               |               |
# |    18    |         Anderson-Cruz         |  41957 Herring Valley Apt. 003  |   399.288.6389x4155   |    09:00 AM   |    06:00 PM   |
# |          |                               |     Frederickberg, SD 89606     |                       |               |               |
# |    19    |           Knox-Smith          | 39934 Catherine Flats Suite 356 |      918.654.7766     |    09:00 AM   |    06:00 PM   |
# |          |                               |      South Sophia, VA 54482     |                       |               |               |
# |    20    |    Smith, Tate and Mcintyre   |   690 Goodwin Unions Suite 662  |      732.330.8222     |    09:00 AM   |    06:00 PM   |
# |          |                               |    New Lorettaview, OH 80453    |                       |               |               |
# +----------+-------------------------------+---------------------------------+-----------------------+---------------+---------------+
#
#
# Table: Employee
# +-------------+------------+-----------+---------------+-------------------------------------+------------------------+-----------------------------+--------------------------------+------------+---------+----------+
# | employee_id | first_name | last_name | date_of_birth |               position              |     contact_number     |            email            |            address             | hire_date  |  salary | store_id |
# +-------------+------------+-----------+---------------+-------------------------------------+------------------------+-----------------------------+--------------------------------+------------+---------+----------+
# |      1      |  Jonathan  |  Russell  |   1971-11-14  |       Administrator, education      |      436.215.3828      | victoriasanchez@example.org | 53225 Reese Heights Suite 119  | 2022-01-01 | 47231.0 |    10    |
# |             |            |           |               |                                     |                        |                             |     Marshallport, PA 30932     |            |         |          |
# |      2      |   Kelly    |  Johnson  |   1924-09-02  |            Advice worker            |      847-343-3853      |      gbell@example.com      |      331 Carlson Orchard       | 2022-04-11 | 94986.0 |    9     |
# |             |            |           |               |                                     |                        |                             |      Stevenport, IL 56175      |            |         |          |
# |      3      |    John    | Hernandez |   1997-11-01  |          Financial adviser          |    +1-905-417-2474     | ericksonmichael@example.org |        049 Jones Locks         | 2021-06-20 | 97884.0 |    9     |
# |             |            |           |               |                                     |                        |                             |      Gibsonfurt, WI 56677      |            |         |          |
# |      4      |   Sheri    |   Oneill  |   1963-03-16  | Engineer, broadcasting (operations) |    +1-539-799-7545     |    jmartinez@example.net    |       56123 Ronald Fords       | 2023-03-30 | 70708.0 |    6     |
# |             |            |           |               |                                     |                        |                             |   North Brianbury, IL 19787    |            |         |          |
# |      5      | Elizabeth  |   Jordan  |   2022-05-20  |        Multimedia programmer        |       7422269214       |     ahorton@example.org     |         8673 Jon Ridge         | 2020-09-26 | 40470.0 |    6     |
# |             |            |           |               |                                     |                        |                             |      Kennethton, MD 77484      |            |         |          |
# |      6      |   Billy    |   Harris  |   2000-01-30  | Chartered public finance accountant |      761.340.4011      | williamsontyler@example.org |         191 Cody Ways          | 2021-03-22 | 43686.0 |    1     |
# |             |            |           |               |                                     |                        |                             |      Perryfort, NE 01834       |            |         |          |
# |      7      |   Maria    |   Vance   |   2022-07-04  |           Records manager           |  +1-237-967-0540x669   | deleonpriscilla@example.net |   752 Jacobs Wells Apt. 202    | 2023-01-04 | 69805.0 |    1     |
# |             |            |           |               |                                     |                        |                             |      Pamelabury, IL 20235      |            |         |          |
# |      8      |   James    |    Neal   |   1943-05-07  |            Stage manager            |    519-367-5271x101    |     yvonne11@example.net    | 01278 Frank Junctions Apt. 280 | 2023-03-05 | 43243.0 |    10    |
# |             |            |           |               |                                     |                        |                             |   West Tamaraburgh, KS 27300   |            |         |          |
# |      9      |  Beverly   |   Lyons   |   1978-05-17  |        Primary school teacher       |     (411)961-6430      |   hollowayjoe@example.com   |       PSC 4454, Box 8175       | 2021-06-24 | 97748.0 |    10    |
# |             |            |           |               |                                     |                        |                             |          APO AP 46411          |            |         |          |
# |      10     |  Timothy   |  Herrera  |   1957-02-06  |               Actuary               | 001-838-802-7539x75834 |     ohanson@example.com     |   0007 Malone Dale Apt. 200    | 2021-06-15 | 61592.0 |    10    |
# |             |            |           |               |                                     |                        |                             |      Rochamouth, TX 66528      |            |         |          |
# +-------------+------------+-----------+---------------+-------------------------------------+------------------------+-----------------------------+--------------------------------+------------+---------+----------+
#
#
# Table: Product
# +------------+----------+--------------------------------------------------------------+-------+-------------------+-------------------+--------------------+-----------------+-------------+
# | product_id |   name   |                         description                          | price | quantity_in_stock | reorder_threshold | manufacturing_date | expiration_date | category_id |
# +------------+----------+--------------------------------------------------------------+-------+-------------------+-------------------+--------------------+-----------------+-------------+
# |     1      | citizen  |            Set success million within air bring.             |  66.0 |        583        |         79        |     2020-02-14     |    2022-03-12   |      2      |
# |     2      |   car    |               Might me window season approach.               |  16.0 |        504        |         86        |     2023-05-05     |    2024-03-14   |      9      |
# |     3      | standard |    Sister street class research talk environment factor.     |  87.0 |        364        |         62        |     2021-02-19     |    2022-06-17   |      10     |
# |     4      |   man    |               Couple skin explain party share.               |  85.0 |        816        |         10        |     2023-02-14     |    2023-03-20   |      3      |
# |     5      |   man    |      Western international attorney president boy how.       |  28.0 |        845        |         85        |     2020-12-26     |    2024-03-06   |      7      |
# |     6      |  energy  |                  Any marriage window most.                   |  83.0 |        951        |         78        |     2020-10-31     |    2022-07-09   |      8      |
# |     7      |   lose   | Structure relate hotel I discover individual building could. |  87.0 |        703        |         81        |     2020-11-12     |    2023-03-13   |      4      |
# |     8      |   life   |                 Investment those one reduce.                 |  35.0 |         72        |         19        |     2021-12-15     |    2022-04-22   |      7      |
# |     9      |   say    |           Painting worry present beautiful young.            |  20.0 |        890        |         52        |     2022-01-30     |    2023-10-04   |      3      |
# |     10     |  common  |          Star pretty man likely step be into news.           |  46.0 |         37        |         38        |     2022-11-11     |    2023-08-26   |      6      |
# +------------+----------+--------------------------------------------------------------+-------+-------------------+-------------------+--------------------+-----------------+-------------+
#
#
# Table: Category
# +-------------+-----------+----------------------------------------------------------------+
# | category_id |    name   |                          description                           |
# +-------------+-----------+----------------------------------------------------------------+
# |      1      |   month   |      Admit scene common perform form various save peace.       |
# |      2      |    end    | Understand before information light worry onto responsibility. |
# |      3      | represent |        Particular already stand artist language we of.         |
# |      4      |  require  |    Choose pick study collection rock investment recognize.     |
# |      5      |   begin   |            Fall political grow process body those.             |
# |      6      |   almost  |                       Rule sister offer.                       |
# |      7      |   other   |        Dinner parent easy energy community back along.         |
# |      8      |  science  |           Begin help increase chair away dog south.            |
# |      9      |   cover   |    Newspaper catch leg feeling role rich treatment usually.    |
# |      10     |  remember |                  Region from during another.                   |
# +-------------+-----------+----------------------------------------------------------------+
#
#
# Table: Customer
# +-------------+------------+-----------+---------------+---------------------+-----------------------------+---------------------------------+
# | customer_id | first_name | last_name | date_of_birth |    contact_number   |            email            |             address             |
# +-------------+------------+-----------+---------------+---------------------+-----------------------------+---------------------------------+
# |      1      |  Jessica   |   Harris  |   1965-06-22  |     283-589-6431    |   dixoncharles@example.net  |         25364 Shaw Pines        |
# |             |            |           |               |                     |                             |       Emilyshire, TX 73011      |
# |      2      |  Heather   |   Young   |   2023-02-20  |  932.773.0209x1875  |     vcompton@example.net    |  41413 Lindsay Corner Suite 409 |
# |             |            |           |               |                     |                             |      North Andrew, GU 73248     |
# |      3      |   James    |     Ho    |   2021-05-06  |   +1-480-241-9563   |   kyleharrison@example.com  |   35479 Nathan Field Apt. 551   |
# |             |            |           |               |                     |                             |        Maryport, MN 14161       |
# |      4      |   Craig    |    Lee    |   1940-08-31  |  (255)440-5597x608  | georgekatherine@example.net | 6039 Catherine Harbor Suite 593 |
# |             |            |           |               |                     |                             |        Bushview, NJ 65816       |
# |      5      |  Gregory   |   Morris  |   1952-09-18  |      5207089459     |    kathleen68@example.org   |    434 Thomas Ports Apt. 246    |
# |             |            |           |               |                     |                             |      Hendrixfort, MP 73715      |
# |      6      |  Michael   |   Rivera  |   1919-12-26  |     413-547-7390    |  courtneyflores@example.net |         280 Anthony Spur        |
# |             |            |           |               |                     |                             |       Novakstad, PW 08253       |
# |      7      |  Charlene  |  Fuentes  |   1983-03-15  | (413)816-7655x62756 |   allisonclark@example.net  |     40961 Bill Well Apt. 492    |
# |             |            |           |               |                     |                             |     North Brittany, MS 42460    |
# |      8      |  Jeffrey   |  Collier  |   2005-06-01  | +1-685-571-1515x262 |    ndominguez@example.org   |       99367 Robbins Drive       |
# |             |            |           |               |                     |                             |     Alexandriabury, IL 02660    |
# |      9      |  Zachary   |   Watson  |   2010-02-02  |  852-774-2352x9376  |     justin76@example.org    |         789 Ann Centers         |
# |             |            |           |               |                     |                             |    North Nicoleton, HI 87080    |
# |      10     |   Billy    |   Scott   |   1978-10-20  |    (458)986-9390    |     otaylor@example.com     |    8389 Roman Fields Apt. 938   |
# |             |            |           |               |                     |                             |      Isaiahshire, NY 91528      |
# +-------------+------------+-----------+---------------+---------------------+-----------------------------+---------------------------------+
#
#
# Table: SalesTransaction
# +----------------+------------------+----------------+--------------+-------------+
# | transaction_id | transaction_date | payment_method | total_amount | customer_id |
# +----------------+------------------+----------------+--------------+-------------+
# |       1        |    2023-01-03    |      Cash      |    372.0     |      4      |
# |       2        |    2023-08-09    |      Cash      |     91.0     |      7      |
# |       3        |    2023-04-02    |  Credit Card   |    203.0     |      5      |
# |       4        |    2023-02-06    |  Credit Card   |    188.0     |      3      |
# |       5        |    2023-02-04    |      Cash      |    176.0     |      6      |
# |       6        |    2023-04-27    | Online Payment |     64.0     |      9      |
# |       7        |    2023-05-05    |      Cash      |    220.0     |      7      |
# |       8        |    2023-03-26    | Online Payment |    357.0     |      1      |
# |       9        |    2023-07-26    | Online Payment |    339.0     |      6      |
# |       10       |    2023-04-26    |      Cash      |    167.0     |      8      |
# +----------------+------------------+----------------+--------------+-------------+
#
#
# Table: TransactionItem
# +---------------------+----------+----------+----------------+------------+
# | transaction_item_id | quantity | subtotal | transaction_id | product_id |
# +---------------------+----------+----------+----------------+------------+
# |          1          |    6     |  2232.0  |       1        |     6      |
# |          2          |    2     |  182.0   |       2        |     4      |
# |          3          |    5     |  1015.0  |       3        |     7      |
# |          4          |    8     |  1504.0  |       4        |     9      |
# |          5          |    7     |  1232.0  |       5        |     5      |
# |          6          |    5     |  320.0   |       6        |     1      |
# |          7          |    1     |  220.0   |       7        |     1      |
# |          8          |    7     |  2499.0  |       8        |     7      |
# |          9          |    3     |  1017.0  |       9        |     6      |
# |          10         |    10    |  1670.0  |       10       |     9      |
# +---------------------+----------+----------+----------------+------------+
#
#
# Table: Supplier
# +-------------+----------------------------+---------------------+------------------------------+------------------------------+
# | supplier_id |            name            |    contact_number   |            email             |           address            |
# +-------------+----------------------------+---------------------+------------------------------+------------------------------+
# |      1      |          Beck Inc          |     981.927.5570    |     teresa44@example.org     |     49961 Jackson Knoll      |
# |             |                            |                     |                              |   Christinebury, VA 46195    |
# |      2      |      Bailey-Thompson       |    (342)745-9152    | kimberlyrobinson@example.org | 011 Campbell Inlet Suite 337 |
# |             |                            |                     |                              |    Garrettshire, AR 76508    |
# |      3      |  Jensen, Lewis and Burton  |  (465)648-6407x0910 |   mckinneyeric@example.org   |      334 Banks Mission       |
# |             |                            |                     |                              |    Valerieport, LA 98504     |
# |      4      |        Shields PLC         |  (688)699-7352x3515 |      rsmith@example.com      |  39817 Cynthia Key Apt. 918  |
# |             |                            |                     |                              |   Samanthahaven, TN 59390    |
# |      5      |       King and Sons        |  (368)992-7754x3990 |   billschultz@example.net    |      950 Mooney Squares      |
# |             |                            |                     |                              |     Robertbury, CA 67234     |
# |      6      |       Castillo Group       | +1-936-369-8398x555 |    ryansmith@example.com     |    1879 Crosby Expressway    |
# |             |                            |                     |                              | North Charlestown, ND 53665  |
# |      7      |         Baker PLC          |  447-860-7815x8833  |    craigjason@example.org    |     5748 Hunt Mountains      |
# |             |                            |                     |                              |   New Markburgh, MO 47507    |
# |      8      | Sanchez, Andrews and Bauer |   929.686.7229x504  |    kimberly12@example.net    |     08100 Collins Drive      |
# |             |                            |                     |                              |     Scottfort, AR 88286      |
# |      9      |        Ramsey Group        |     269-879-8693    |   hillbridget@example.com    |  036 Willie Grove Apt. 440   |
# |             |                            |                     |                              |    South Megan, NV 77699     |
# |      10     |       Thornton-Scott       |  (533)393-3403x343  |    stephen41@example.net     |     8546 Ronald Terrace      |
# |             |                            |                     |                              |   West Johnstad, NM 90113    |
# +-------------+----------------------------+---------------------+------------------------------+------------------------------+
#
#
# Table: Supply
# +-----------+-------------+-------------------+------------+-------------+------------+
# | supply_id | supply_date | quantity_supplied | unit_price | supplier_id | product_id |
# +-----------+-------------+-------------------+------------+-------------+------------+
# |     1     |  2023-06-26 |        100        |    35.0    |      10     |     5      |
# |     2     |  2023-01-23 |         70        |    40.0    |      6      |     1      |
# |     3     |  2023-05-19 |         93        |    35.0    |      1      |     3      |
# |     4     |  2023-06-04 |         77        |    20.0    |      1      |     9      |
# |     5     |  2023-07-15 |         87        |    19.0    |      6      |     2      |
# |     6     |  2023-07-17 |         97        |    14.0    |      8      |     2      |
# |     7     |  2023-07-07 |         20        |    20.0    |      6      |     2      |
# |     8     |  2023-05-18 |         66        |    10.0    |      3      |     6      |
# |     9     |  2023-07-14 |         14        |    42.0    |      7      |     3      |
# |     10    |  2023-06-08 |         75        |    17.0    |      2      |     8      |
# +-----------+-------------+-------------------+------------+-------------+------------+
